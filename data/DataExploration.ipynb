# %%
import pandas as pd

# %%
train = pd.read_csv('train_2011_12_DATA.csv')
test =  pd.read_csv('test_2013_14_DATA.csv')

# %%
print train
# Out:
#       Unnamed: 0  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  RIDRETH3  \
# 0              0         2         1        22         0         3         3
# 1              1         2         2         3         0         1         1
# 2              2         2         1        14         0         5         6
# 3              3         2         2        44         0         3         3
# 4              4         2         2        14         0         4         4
# 5              5         2         1         9         0         3         3
# 6              6         2         1         0        11         5         6
# 7              7         2         1         6         0         5         7
# 8              8         2         1        21         0         5         6
# 9              9         2         1        15         0         5         7
# 10            10         2         1        14         0         1         1
# ...
